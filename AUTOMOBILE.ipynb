# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('automobile_data.csv', sep=',')

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
df.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
df.replace(to_replace =["?", "n.a"],  
                            value ="NaN")
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df = pd.read_csv("automobile_data.csv", na_values={
'price':["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})
print (df)

df.to_csv("automobile_data.csv")
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.price.max()
# Out:
# 45400.0

# %%
# ?df.max
# Out:
# Signature: df.max(axis=None, skipna=None, level=None, numeric_only=None, **kwargs)
# Docstring:
# Return the maximum of the values for the requested axis.
#
#             If you want the *index* of the maximum, use ``idxmax``. This is
#             the equivalent of the ``numpy.ndarray`` method ``argmax``.
#
# Parameters
# ----------
# axis : {index (0), columns (1)}
#     Axis for the function to be applied on.
# skipna : bool, default True
#     Exclude NA/null values when computing the result.
# level : int or level name, default None
#     If the axis is a MultiIndex (hierarchical), count along a
#     particular level, collapsing into a Series.
# numeric_only : bool, default None
#     Include only float, int, boolean columns. If None, will attempt to use
#     everything, then use only numeric data. Not implemented for Series.
# **kwargs
#     Additional keyword arguments to be passed to the function.
#
# Returns
# -------
# Series or DataFrame (if level specified)
#
# ...

# %%
df[['price','company']].max()
# Out:
# price              45400
# company    mercedes-benz
# dtype: object

# %%
import pandas as pd
df = pd.read_csv("automobile_data.csv")
df = df [['company','price']][df.price==df['price'].max()]
df
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
df.loc[df['company'] == 'toyota']
# Out:
#     Unnamed: 0  index company body-style  wheel-base  length engine-type  \
# 48          48     66  toyota  hatchback        95.7   158.7         ohc
# 49          49     67  toyota  hatchback        95.7   158.7         ohc
# 50          50     68  toyota  hatchback        95.7   158.7         ohc
# 51          51     69  toyota      wagon        95.7   169.7         ohc
# 52          52     70  toyota      wagon        95.7   169.7         ohc
# 53          53     71  toyota      wagon        95.7   169.7         ohc
# 54          54     79  toyota      wagon       104.5   187.8        dohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 48             four          62               35   5348.0
# 49             four          62               31   6338.0
# 50             four          62               31   6488.0
# 51             four          62               31   6918.0
# 52             four          62               27   7898.0
# ...

# %%
import pandas as pd
df = pd.read_csv("automobile_data.csv")
car_Manufacturers = df.groupby('company')
toyotaDf = car_Manufacturers.get_group('toyota')
toyotaDf
# Out:
#     Unnamed: 0  index company body-style  wheel-base  length engine-type  \
# 48          48     66  toyota  hatchback        95.7   158.7         ohc
# 49          49     67  toyota  hatchback        95.7   158.7         ohc
# 50          50     68  toyota  hatchback        95.7   158.7         ohc
# 51          51     69  toyota      wagon        95.7   169.7         ohc
# 52          52     70  toyota      wagon        95.7   169.7         ohc
# 53          53     71  toyota      wagon        95.7   169.7         ohc
# 54          54     79  toyota      wagon       104.5   187.8        dohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 48             four          62               35   5348.0
# 49             four          62               31   6338.0
# 50             four          62               31   6488.0
# 51             four          62               31   6918.0
# 52             four          62               27   7898.0
# ...

# %%
df.loc[df['body-style']=='wagon']
# Out:
#     Unnamed: 0  index        company body-style  wheel-base  length  \
# 6            6      6           audi      wagon       105.8   192.7
# 18          18     27          honda      wagon        96.5   157.1
# 33          33     45  mercedes-benz      wagon       110.0   190.9
# 43          43     56         nissan      wagon        94.5   170.2
# 51          51     69         toyota      wagon        95.7   169.7
# 52          52     70         toyota      wagon        95.7   169.7
# 53          53     71         toyota      wagon        95.7   169.7
# 54          54     79         toyota      wagon       104.5   187.8
# 60          60     88          volvo      wagon       104.3   188.8
#
#    engine-type num-of-cylinders  horsepower  average-mileage    price
# 6          ohc             five         110               19  18920.0
# 18         ohc             four          76               30   7295.0
# 33         ohc             five         123               22  28248.0
# ...

# %%
import pandas as pd
df = pd.read_csv("automobile_data.csv")
car_Manufacturerss = df.groupby('body-style')
toyotaDfs = car_Manufacturerss.get_group('wagon')
toyotaDfs
# Out:
#     Unnamed: 0  index        company body-style  wheel-base  length  \
# 6            6      6           audi      wagon       105.8   192.7
# 18          18     27          honda      wagon        96.5   157.1
# 33          33     45  mercedes-benz      wagon       110.0   190.9
# 43          43     56         nissan      wagon        94.5   170.2
# 51          51     69         toyota      wagon        95.7   169.7
# 52          52     70         toyota      wagon        95.7   169.7
# 53          53     71         toyota      wagon        95.7   169.7
# 54          54     79         toyota      wagon       104.5   187.8
# 60          60     88          volvo      wagon       104.3   188.8
#
#    engine-type num-of-cylinders  horsepower  average-mileage    price
# 6          ohc             five         110               19  18920.0
# 18         ohc             four          76               30   7295.0
# 33         ohc             five         123               22  28248.0
# ...

# %%
# COUNT TOTAL CARS PER COMPANY

# %%
df = pd.read_csv("automobile_data.csv")
df['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# nissan           5
# mazda            5
# mercedes-benz    4
# audi             4
# volkswagen       4
# mitsubishi       4
# honda            3
# jaguar           3
# alfa-romero      3
# chevrolet        3
# porsche          3
# isuzu            3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
df['body-style'].value_counts()
# Out:
# sedan          32
# hatchback      15
# wagon           9
# convertible     3
# hardtop         2
# Name: body-style, dtype: int64

# %%
# FIND EACH COMPANY`S HIGHEST PRICE CAR

# %%
comp_grp = df.groupby('company')
highest = comp_grp['company','price'].max()
highest
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %%
# FIND THE AVERAGE MILEAGE OF EACH CAR MAKING COMPANY

# %%
comp_grp = df.groupby('company')
comp_grp['company','average-mileage'].mean()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %%
# SORT ALL CARS BY PRICE COLUMN

# %%
df.sort_values(by=['price'], ascending = False)
# Out:
#     Unnamed: 0  index        company   body-style  wheel-base  length  \
# 35          35     47  mercedes-benz      hardtop       112.0   199.2
# 11          11     14            bmw        sedan       103.5   193.8
# 34          34     46  mercedes-benz        sedan       120.9   208.1
# 46          46     62        porsche  convertible        89.5   168.9
# 12          12     15            bmw        sedan       110.0   197.0
# ..         ...    ...            ...          ...         ...     ...
# 27          27     36          mazda    hatchback        93.1   159.1
# 13          13     16      chevrolet    hatchback        88.4   141.1
# 22          22     31          isuzu        sedan        94.5   155.9
# 23          23     32          isuzu        sedan        94.5   155.9
# 47          47     63        porsche    hatchback        98.4   175.7
#
#    engine-type num-of-cylinders  horsepower  average-mileage    price
# ...

# %%
# CONCATENATE TWO DATAFRAMES

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
ge = pd.DataFrame.from_dict(GermanCars)
ge
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
ja = pd.DataFrame.from_dict(japaneseCars)
ja
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
k = [ge, ja]
cc = pd.concat(k, keys = ['German','Japan'])
cc
# Out:
#               Company   Price
# German 0         Ford   23845
#        1     Mercedes  171995
#        2          BMV  135925
#        3         Audi   71400
# Japan  0       Toyota   29995
#        1        Honda   23600
#        2       Nissan   61500
#        3  Mitsubishi    58900

# %%
# MERGE TWO DATAFRAMES

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %%
cp = pd.DataFrame(Car_Price)
cp
# Out:
#   Company   Price
# 0  Toyota   23845
# 1   Honda   17995
# 2     BMV  135925
# 3    Audi   71400

# %%
hor = pd.DataFrame(car_Horsepower)
hor
# Out:
#   Company  horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %%
pd.merge(cp, hor, on='Company')
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %%
# Out:
# array([ 5, 10, 15])

# %%
pd.merge(cp, hor)
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160

# %%
seri = pd.Series([121,200,150,99])

seri.values
# Out:
# array([121, 200, 150,  99], dtype=int64)

# %%
var1 = [15,45,44,33,66]
var2 = [33,55,66,22,33]
df = pd.DataFrame({'var1':[15,45,44,33,66],'var2':[33,55,66,22,33]})

df[(df.var1 > 15)][[ "var1","var2"]]
# Out:
#    var1  var2
# 1    45    55
# 2    44    66
# 3    33    22
# 4    66    33

# %%
var1 = [15,45,44,33,66]
var2 = [33,55,66,22,33]
df = pd.DataFrame({'var1':[15,45,44,33,66],'var2':[33,55,66,22,33]})

df[(df.var1 > 15)][[ "var1"]]
# Out:
#    var1
# 1    45
# 2    44
# 3    33
# 4    66

# %%
type(df[(df.var1 > 15)][[ "var1"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[(df.var1 > 15), ["var1","var2"]]
# Out:
#    var1  var2
# 1    45    55
# 2    44    66
# 3    33    22
# 4    66    33

# %%
import numpy as np
m = np.arange(1,7).reshape((3,2))
pd.DataFrame(m, columns = ["var1","var2"])
# Out:
#    var1  var2
# 0     1     2
# 1     3     4
# 2     5     6

# %%
# ?describe
# Out:
# Object `describe` not found.
